# %%
from utils import cv, plt, calculate_face_histogram, calculate_skin_mask

# %%
forehead, hist = calculate_face_histogram()

# %%
plt.imshow(cv.cvtColor(forehead, cv.COLOR_BGR2RGB))

# %%
calculate_skin_mask(hist)
